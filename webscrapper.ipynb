# %%
import requests
from urllib.request import urlopen
import logging
from bs4 import BeautifulSoup as bs

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone15"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone15'

# %%
import requests
from bs4 import BeautifulSoup
session = requests.Session()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://www.google.com'
}

try:
    response = session.get(flipkart_url, headers=headers)
    response.raise_for_status()  
    html_content = response.text

    print(f"Type of html_content: {type(html_content)}")
    soup = BeautifulSoup(html_content, 'html.parser')
    print(f"Type of soup: {type(soup)}")
    desired_div = soup.findAll("div", {"class": "cPHDOP col-12-12"})

    if desired_div:
        print(desired_div)
    else:
        print("Div with the specified class not found.")

except requests.HTTPError as e:
    print(e)
# Out:
# Type of html_content: <class 'str'>
# Type of soup: <class 'bs4.BeautifulSoup'>
# ...

# %%
bigbox = desired_div

# %%
len(bigbox)
# Out:
# 30

# %%
bigbox[3].div.div.div.a['href']
# Out:
# '/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYO7HQ2L&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=cf5280c3-1d32-4ea0-8a24-04b41cbe351e.MOBGTAGPAQNVFZZY.SEARCH&ppt=None&ppn=None&ssid=fzgjgg3n4w0000001722923013693&qH=1827ac0d826493c5'

# %%
del bigbox[0:3]

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYO7HQ2L&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=cf5280c3-1d32-4ea0-8a24-04b41cbe351e.MOBGTAGPAQNVFZZY.SEARCH&ppt=None&ppn=None&ssid=fzgjgg3n4w0000001722923013693&qH=1827ac0d826493c5
# https://www.flipkart.com/apple-iphone-15-black-128-gb/p/itm6ac6485515ae4?pid=MOBGTAGPTB3VS24W&lid=LSTMOBGTAGPTB3VS24WVZNSC6&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=cf5280c3-1d32-4ea0-8a24-04b41cbe351e.MOBGTAGPTB3VS24W.SEARCH&ppt=None&ppn=None&ssid=fzgjgg3n4w0000001722923013693&qH=1827ac0d826493c5
# ...

# %%
productlink = "https://www.flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-15-blue-256-gb/p/itm986f66c53cae4?pid=MOBGTAGPNEZZY2YR&lid=LSTMOBGTAGPNEZZY2YRE1FCIG&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=cf5280c3-1d32-4ea0-8a24-04b41cbe351e.MOBGTAGPNEZZY2YR.SEARCH&ppt=None&ppn=None&ssid=fzgjgg3n4w0000001722923013693&qH=1827ac0d826493c5'

# %%
product_req = requests.get(productlink)

# %%
product_req
# Out:
# <Response [500]>

# %%
bs(product_req.text)
# Out:
# <html><body><h1>500 Internal Server Error</h1>
# An internal server error occurred.
# </body></html>

# %%
import requests

url = productlink
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Referer": "https://www.google.com"
}

try:
    response = requests.get(url, headers=headers, timeout=10)
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)
    print(response.text)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.f9cc90.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.f32dbb.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property
# ...

# %%
product_html = bs(response.text)

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.find_all("div",{"class":"RcXBOT"})

# %%
len(comment_box)
# Out:
# 11

# %%
type(comment_box)
# Out:
# bs4.element.ResultSet

# %%
comment_box[0]
# Out:
# <div class="RcXBOT"><div class="col"><div class="col EPCmJX"><div class="row"><div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div><p class="z9E0IG">Brilliant</p></div><div class="row"><div class="ZmyHeo"><div><div class="">moving from android to apple is a surreal experience. still apple could focus on more flexibility towards the apps.</div><span class="wTYmpv"><span>READ MORE</span></span></div></div></div><div class="xmAgz5 pVVA7t"><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_78382fa1a7104b76a4ba6bbba5785bc7.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_cd3f2cc05d6f483faf418e17ace7224c.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/1
# ...

# %%
comment_box[0].div.div.find_all('p',{'class':'_2NsDsF AwS1CA'})[0].text
# Out:
# 'Sajib Das'

# %%
for i in range(len(comment_box)):
    if comment_box[i] is not None:
        div_element = comment_box[i].div
        if div_element is not None:
            inner_div = div_element.div
            if inner_div is not None:
                paragraphs = inner_div.find_all('p', {'class': '_2NsDsF AwS1CA'})
                if paragraphs:
                    comment_text = paragraphs[0].text
                    print(comment_text)
# Out:
# Sajib Das
# Siddharth Malhotra
# Prithivi Boruah
# Ajin V
# Mousam  Guha Roy
# Sheetla Prasad Maurya
# Talim (sk)
# mohit  yadav
# Nikhil Kumar
# Flipkart Customer

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in range(len(comment_box)):
    if comment_box[i] is not None:
        div_element = comment_box[i].div
        if div_element is not None:
            inner_dev = div_element.div
            if inner_dev is not None:
                inin_dev = inner_dev.div
                if inin_dev is not None:
                    ininin_dev = inin_dev.div
                    if ininin_dev:
                        comment_text = ininin_dev.text
                        print(comment_text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 5
# 5

# %%
## Comment Header

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Brilliant'

# %%
for i in range(len(comment_box)):
    if comment_box[i] is not None:
        div_element = comment_box[i].div
        if div_element is not None:
            inner_dev = div_element.div
            if inner_dev is not None:
                inin_dev = inner_dev.div
                if inin_dev is not None:
                    ininin_p = inin_dev.p
                    if ininin_p:
                        comment_text = ininin_p.text
                        print(comment_text)
# Out:
# Brilliant
# Perfect product!
# Just wow!
# Mind-blowing purchase
# Good choice
# Worth the money
# Highly recommended
# Classy product
# Awesome
# Worth every penny

# %%
## Comment

# %%
comment_box[0].div.div.find_all('div',{"class":''})[0].text
# Out:
# 'moving from android to apple is a surreal experience. still apple could focus on more flexibility towards the apps.READ MORE'

# %%
for i in range(len(comment_box)):
    if comment_box[i] is not None:
        inner_dev = comment_box[i].div
        if inner_dev is not None:
            div_element = inner_dev.div
            if div_element is not None:
                inin = div_element.find_all('div',{"class":''})
                if inin:
                    comment_text = inin[0].text
                    print(comment_text)
# Out:
# moving from android to apple is a surreal experience. still apple could focus on more flexibility towards the apps.READ MORE
# Nice product with all features specially its looks and camera battery backup is goodYou should buy it without any issuesREAD MORE
# Camera Quality Is Improved Loving ItREAD MORE
# High quality camera😍READ MORE
# Very niceREAD MORE
# Best mobile phoneCamera quality is very nice Battery backup is very good Sound quality is amazing.READ MORE
# I love this phone. The camera is amazing: its I am so happyREAD MORE
# Nice ❤️READ MORE
# Switch from OnePlus to iPhone I am stunned with camera performance. Everything is perfect on  iPhone 15.READ MORE
# Awesome photography experience. Battery backup is good . Display is much better than 14 version.READ MORE
